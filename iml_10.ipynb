# %% [markdown]
# # Introduction to Machine Learning - Exercise 10
# Goal of the excercise is to learn how to save trained models and use selected advanced libraries like Plotly or Optuna.
#
#
# ![meme01](https://github.com/lubsar/EFREI-Introduction-to-Machine-Learning/blob/main/images/fml_12_meme_01.png?raw=true)

# %%
# For Google Colab
# !pip install optuna

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import optuna
import joblib

import sklearn.datasets as skd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, accuracy_score

# %% [markdown]
# # 📊 Plotly
# https://plotly.com/python/getting-started/
#
# * The plotly Python library is an interactive, open-source plotting library that supports over chart types covering a wide range of statistical, financial, geographic or scientific use-cases
# * Built on top of the Plotly JavaScript library (plotly.js)
# * Plotly enables Python users to create **interactive web-based visualizations** that can be displayed in Jupyter notebooks

# %% [markdown]
# ## 📒 Here we have some examples of commonly used plots
# * 💡 Express API is easy to grasp and it is very similar to Seaborn

# %% [markdown]
# ## Scatter plot

# %%
df = px.data.iris()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
px.scatter(df, x="sepal_width", y="sepal_length", color="species", symbol="species")

# %% [markdown]
# ## Line plot

# %%
df = px.data.gapminder().query("continent == 'Oceania'")
df.head()
# Out:
#       country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 60  Australia   Oceania  1952    69.12   8691212  10039.59564       AUS
# 61  Australia   Oceania  1957    70.33   9712569  10949.64959       AUS
# 62  Australia   Oceania  1962    70.93  10794968  12217.22686       AUS
# 63  Australia   Oceania  1967    71.10  11872264  14526.12465       AUS
# 64  Australia   Oceania  1972    71.93  13177000  16788.62948       AUS
#
#     iso_num
# 60       36
# 61       36
# 62       36
# 63       36
# 64       36

# %%
px.line(df, x='year', y='lifeExp', color='country', markers=True)

# %% [markdown]
# ## Bar plot

# %%
df = px.data.medals_long()
df.head()
# Out:
#         nation   medal  count
# 0  South Korea    gold     24
# 1        China    gold     10
# 2       Canada    gold      9
# 3  South Korea  silver     13
# 4        China  silver     15

# %%
px.bar(df, x="medal", y="count", color="nation", text="nation", barmode='group')

# %% [markdown]
# ## Box plot

# %%
df = px.data.gapminder().query("continent == 'Oceania'")
df.head()
# Out:
#       country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 60  Australia   Oceania  1952    69.12   8691212  10039.59564       AUS
# 61  Australia   Oceania  1957    70.33   9712569  10949.64959       AUS
# 62  Australia   Oceania  1962    70.93  10794968  12217.22686       AUS
# 63  Australia   Oceania  1967    71.10  11872264  14526.12465       AUS
# 64  Australia   Oceania  1972    71.93  13177000  16788.62948       AUS
#
#     iso_num
# 60       36
# 61       36
# 62       36
# 63       36
# 64       36

# %%
px.box(df, x='country', color="country", y="lifeExp")

# %% [markdown]
# ## Heatmap

# %%
df = px.data.iris()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
df_corr = df.iloc[:, :-2].corr()
df_corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
fig = px.imshow(df_corr, text_auto=True, color_continuous_scale="blues", aspect="auto")
fig.update_xaxes(side="bottom")
fig.show()

# %% [markdown]
# ## 📌 Parallel categories diagram
# * How to read it?

# %%
df = pd.read_csv('https://github.com/lubsar/EFREI-Introduction-to-Machine-Learning/raw/refs/heads/main/datasets/titanic.csv', index_col=0)
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
px.parallel_categories(df, dimensions=['Embarked', 'Sex', 'Survived'], color="Survived", color_continuous_scale=px.colors.diverging.Spectral)

# %% [markdown]
# ![meme02](https://github.com/lubsar/EFREI-Introduction-to-Machine-Learning/blob/main/images/fml_12_meme_02.jpg?raw=true)m

# %% [markdown]
# # 🚀 Optuna
# https://optuna.org/
#
# * An open source hyperparameter optimization framework to automate hyperparameter search
# * You can use it with any machine learning or deep learning framework
#     * Scikit-learn, TF2, PyTorch, Keras, ...

# %% [markdown]
# ## ⚡ Using Optuna is very simple
# * You just need to define the `objective` which will be used for each trial
# * Then you define the parameter ranges through `suggest_XYZ` function and use is as a regular parameter
# * After that you can start tuning the parameters

# %%
X, y = skd.load_iris(return_X_y=True, as_frame=True)

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
def objective(trial, X, y):
    n_estimators = trial.suggest_int('n_estimators', 2, 20)
    max_depth = int(trial.suggest_int('max_depth', 1, 32))
    criterion = trial.suggest_categorical('criterion', ["gini", "entropy"])
    random_state = 13
    
    clf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, criterion=criterion, random_state=random_state)

    acc_scorer = make_scorer(accuracy_score)
    cv_res = cross_val_score(clf, X, y, n_jobs=-1, cv=5, scoring=acc_scorer)

    return np.mean(cv_res)

# %%
study = optuna.create_study(direction='maximize', storage="sqlite:///db.sqlite3", study_name="Iris-RF-Tuning")
study.optimize(lambda trial: objective(trial, X, y), n_trials=100)

trial = study.best_trial

print('Accuracy: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))
# Out:
# [I 2025-11-25 14:37:27,977] A new study created in RDB with name: Iris-RF-Tuning
# [I 2025-11-25 14:37:29,821] Trial 0 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 19, 'max_depth': 13, 'criterion': 'gini'}. Best is trial 0 with value: 0.9466666666666667.
# [I 2025-11-25 14:37:31,183] Trial 1 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 18, 'max_depth': 13, 'criterion': 'gini'}. Best is trial 0 with value: 0.9466666666666667.
# [I 2025-11-25 14:37:32,626] Trial 2 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 16, 'max_depth': 28, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9533333333333334.
# [I 2025-11-25 14:37:34,043] Trial 3 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 11, 'max_depth': 32, 'criterion': 'gini'}. Best is trial 2 with value: 0.9533333333333334.
# [I 2025-11-25 14:37:34,102] Trial 4 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 19, 'max_depth': 14, 'criterion': 'gini'}. Best is trial 2 with value: 0.9533333333333334.
# [I 2025-11-25 14:37:34,164] Trial 5 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 17, 'max_depth': 2, 'criterion': 'gini'}. Best is trial 2 with value: 0.9533333333333334.
# [I 2025-11-25 14:37:34,225] Trial 6 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 11, 'max_depth': 10, 'criterion': 'gini'}. Best is trial 2 with value: 0.9533333333333334.
# [I 2025-11-25 14:37:34,281] Trial 7 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 17, 'max_depth': 10, 'criterion': 'gini'}. Best is trial 2 with value: 0.9533333333333334.
# [I 2025-11-25 14:37:34,337] Trial 8 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 6, 'max_depth': 27, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9533333333333334.
# [I 2025-11-25 14:37:34,382] Trial 9 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 7, 'max_depth': 12, 'criterion': 'gini'}. Best is trial 2 with value: 0.9533333333333334.
# [I 2025-11-25 14:37:34,432] Trial 10 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 2, 'max_depth': 23, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9533333333333334.
# [I 2025-11-25 14:37:34,507] Trial 11 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 14, 'max_depth': 21, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9533333333333334.
# [I 2025-11-25 14:37:34,563] Trial 12 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 15, 'max_depth': 3, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9533333333333334.
# [I 2025-11-25 14:37:34,622] Trial 13 finished with value: 0.96 and parameters: {'n_estimators': 13, 'max_depth': 7, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:34,682] Trial 14 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 14, 'max_depth': 32, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:34,745] Trial 15 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 9, 'max_depth': 7, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:34,809] Trial 16 finished with value: 0.96 and parameters: {'n_estimators': 13, 'max_depth': 21, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:34,871] Trial 17 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 9, 'max_depth': 19, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:34,930] Trial 18 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 12, 'max_depth': 6, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:34,992] Trial 19 finished with value: 0.96 and parameters: {'n_estimators': 13, 'max_depth': 17, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:35,055] Trial 20 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 9, 'max_depth': 22, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:35
 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,193] Trial 86 finished with value: 0.96 and parameters: {'n_estimators': 11, 'max_depth': 22, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,256] Trial 87 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 8, 'max_depth': 24, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,341] Trial 88 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 18, 'max_depth': 15, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,405] Trial 89 finished with value: 0.96 and parameters: {'n_estimators': 19, 'max_depth': 9, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,466] Trial 90 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 12, 'max_depth': 14, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,531] Trial 91 finished with value: 0.96 and parameters: {'n_estimators': 13, 'max_depth': 18, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,595] Trial 92 finished with value: 0.96 and parameters: {'n_estimators': 13, 'max_depth': 17, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,655] Trial 93 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 12, 'max_depth': 16, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,714] Trial 94 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 14, 'max_depth': 19, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,778] Trial 95 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 16, 'max_depth': 7, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,839] Trial 96 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 13, 'max_depth': 21, 'criterion': 'gini'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,902] Trial 97 finished with value: 0.96 and parameters: {'n_estimators': 15, 'max_depth': 18, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:39,961] Trial 98 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 12, 'max_depth': 20, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# [I 2025-11-25 14:37:40,025] Trial 99 finished with value: 0.96 and parameters: {'n_estimators': 11, 'max_depth': 23, 'criterion': 'entropy'}. Best is trial 13 with value: 0.96.
# Accuracy: 0.96
# Best hyperparameters: {'n_estimators': 13, 'max_depth': 7, 'criterion': 'entropy'}

# %% [markdown]
# ## 💡 Dashboard
# * Logs are hard to read - it is usually better to vizualize the tuning process
# * You have two options with `Optuna`
#     * You can use the basic online tool https://optuna.github.io/optuna-dashboard/
#     * You can run local instance of https://github.com/optuna/optuna-dashboard for more advanced usage
#
# ![meme03](https://github.com/lubsar/EFREI-Introduction-to-Machine-Learning/blob/main/images/fml_12_meme_03.jpg?raw=true)

# %% [markdown]
# # ⚡ Model deploy
# * How are ML/DL models used in production?
#     * Do we train it every time from scratch?
# * How would you deploy the model?

# %% [markdown]
# ## Train the model on full data with the best parameter setup

# %%
params = study.best_trial.params
params
# Out:
# {'n_estimators': 13, 'max_depth': 7, 'criterion': 'entropy'}

# %%
clf = RandomForestClassifier(**params, random_state=13)

# %%
clf.fit(X, y)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=7, n_estimators=13,
#                        random_state=13)

# %%
df_feat_imp = pd.DataFrame({'Feature': X.columns, 'Importance': clf.feature_importances_}).sort_values(by='Importance')
df_feat_imp
# Out:
#              Feature  Importance
# 1   sepal width (cm)    0.023446
# 0  sepal length (cm)    0.060322
# 2  petal length (cm)    0.375624
# 3   petal width (cm)    0.540607

# %%
px.bar(df_feat_imp, y='Feature', x='Importance', orientation='h')

# %%
y_pred = clf.predict(X)
accuracy_score(y_true=y, y_pred=y_pred)
# Out:
# 1.0

# %% [markdown]
# # Save the model using `joblib`
# * There are other alternatives
#     * https://skops.readthedocs.io/en/stable/
#     * https://onnx.ai/sklearn-onnx/

# %%
filename = 'rf_best.bin'
joblib.dump(clf, filename)
# Out:
# ['rf_best.bin']

# %% [markdown]
# # 📈 Load the model from disk

# %%
loaded_model = joblib.load(filename)

# %% [markdown]
# ## Check if everything works fine 🙂

# %%
y_pred = loaded_model.predict(X)
accuracy_score(y_true=y, y_pred=y_pred)
# Out:
# 1.0

# %%
df_feat_imp = pd.DataFrame({'Feature': X.columns, 'Importance': loaded_model.feature_importances_}).sort_values(by='Importance')
df_feat_imp
# Out:
#              Feature  Importance
# 1   sepal width (cm)    0.023446
# 0  sepal length (cm)    0.060322
# 2  petal length (cm)    0.375624
# 3   petal width (cm)    0.540607

# %%
px.bar(df_feat_imp, y='Feature', x='Importance', orientation='h')

# %% [markdown]
# ![meme04](https://github.com/lubsar/EFREI-Introduction-to-Machine-Learning/blob/main/images/thats_all.jpg?raw=true)
